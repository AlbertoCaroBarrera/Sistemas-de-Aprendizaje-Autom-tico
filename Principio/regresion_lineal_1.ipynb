# %%
# Paso 1: Importar bibliotecas
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# Paso 2: Crear los datos (tamaño de la casa en metros cuadrados y precios)
# Datos simulados
metros_cuadrados = np.array([50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150]).reshape(-1, 1)
precios = np.array([150000, 172000, 190000, 210500, 230000, 250000, 232000, 290000, 310090, 350000, 350000])

# Paso 3: Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(metros_cuadrados, precios, test_size=0.2, random_state=42)

# Paso 4: Crear el modelo de regresión lineal y entrenarlo
modelo = LinearRegression()
modelo.fit(X_train, y_train)

# Paso 5: Realizar predicciones
predicciones = modelo.predict(X_test)

# Mostrar los coeficientes y el intercepto
print(f"Coeficiente de regresión (pendiente): {modelo.coef_[0]}")
print(f"Intercepto: {modelo.intercept_}")

# Paso 6: Gráfica con los datos y la línea de regresión
plt.figure(figsize=(8, 6))
plt.scatter(metros_cuadrados, precios, color='blue', label='Datos reales')
plt.plot(metros_cuadrados, modelo.predict(metros_cuadrados), color='red', label='Línea de regresión')

# Etiquetas y leyenda
plt.title('Regresión Lineal: Predicción del Precio de una Casa')
plt.xlabel('Tamaño de la casa (m²)')
plt.ylabel('Precio (USD)')
plt.legend()
plt.grid(True)
plt.show()

# Paso 7: Predicción para una casa de 125 metros cuadrados
metros_nueva_casa = np.array([[125]])
precio_predicho = modelo.predict(metros_nueva_casa)
print(f"El precio predicho para una casa de 125 metros cuadrados es: ${precio_predicho[0]:,.2f} USD")
# Out:
# Coeficiente de regresión (pendiente): 1938.5789473684215
# Intercepto: 51792.63157894733
# El precio predicho para una casa de 125 metros cuadrados es: $294,115.00 USD
